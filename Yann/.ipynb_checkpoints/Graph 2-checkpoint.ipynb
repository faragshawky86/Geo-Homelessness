# %%
# Dependencies
# %matplotlib inline
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import requests
from splinter import Browser
import time
import pandas as pd

# %%
#Create dictionary which we will use to acquire state abbrevation strings
#The value of this dictionary is mainly to provide us with the reverse dictionary which we create later
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY',
}
#create extra key value pairs for DC and PR
us_state_abbrev['Washington, DC'] = 'DC'
us_state_abbrev['Puerto Rico'] = 'PR'

# %%
#Create a reverse of the State abbrevation dictionary which we will use to convert abbrevations to State values 
reverse_us_state_abbrev = {}
for key, val in us_state_abbrev.items():
    reverse_us_state_abbrev[val] = key

# %%
ann_home_df = pd.read_csv("dataframes/annual_homelessness.csv")

# %%
ann_home_df.head()
# Out:
#    Unnamed: 0 state    2018    2017    2016    2015    2014    2013    2012  \
# 0           0    AK    2016    1845    1940    1956    1784    1946    1913
# 1           1    AL    3434    3793    4111    3970    4561    4689    5209
# 2           2    AR    2712    2467    2463    2560    2936    3812    4214
# 3           3    AZ    9865    8947    9707    9896   10495   10562   11302
# 4           4    CA  129972  131532  118142  115738  113952  118552  120098
#
#      2011    2010    2009    2008    2007
# 0    2128    1863    1992    1646    1642
# 1    5558    6046    6080    5387    5452
# 2    3424    2762    2852    3255    3836
# 3   10504   13711   14721   12488   14646
# 4  125128  123480  123678  136531  138986

# %%
#Create an empty list to append the full state names
fullState = []

#use the reverse dictionary to acquire full state names from the abbreviations 
for state in ann_home_df['state']:
    fullState.append(reverse_us_state_abbrev[state])

# %%
ann_home_df['State'] = fullState

# %%
ann_home_df.head()
# Out:
#    Unnamed: 0 state    2018    2017    2016    2015    2014    2013    2012  \
# 0           0    AK    2016    1845    1940    1956    1784    1946    1913
# 1           1    AL    3434    3793    4111    3970    4561    4689    5209
# 2           2    AR    2712    2467    2463    2560    2936    3812    4214
# 3           3    AZ    9865    8947    9707    9896   10495   10562   11302
# 4           4    CA  129972  131532  118142  115738  113952  118552  120098
#
#      2011    2010    2009    2008    2007       State
# 0    2128    1863    1992    1646    1642      Alaska
# 1    5558    6046    6080    5387    5452     Alabama
# 2    3424    2762    2852    3255    3836    Arkansas
# 3   10504   13711   14721   12488   14646     Arizona
# 4  125128  123480  123678  136531  138986  California

# %%
""" export data into json format... list of lists with two items for each year. read data into js using js dictionaries. after reading into js use plotly to plot each """
# Out:
# ' export data into json format... list of lists with two items for each year. read data into js using js dictionaries. after reading into js use plotly to plot each '

# %%
Population_df = pd.read_csv("dataframes/State_Population.csv")

# %%
Population_df.head()
# Out:
#         STATE        2010        2011        2012        2013        2014  \
# 0     Alabama   4712651.0   4747424.0   4777326.0   4799277.0   4817678.0
# 1      Alaska    691189.0    700703.0    711139.0    720316.0    728300.0
# 2     Arizona   6246816.0   6337373.0   6410979.0   6479703.0   6561516.0
# 3    Arkansas   2872684.0   2895928.0   2916372.0   2933369.0   2947036.0
# 4  California  36637290.0  36969200.0  37325068.0  37659181.0  38066920.0
#
#          2015        2016        2017
# 0   4830620.0   4841164.0   4850771.0
# 1    733375.0    736855.0    738565.0
# 2   6641928.0   6728577.0   6809946.0
# 3   2958208.0   2968472.0   2977944.0
# 4  38421464.0  38654206.0  38982847.0

# %%
Yearlist = Population_df.columns[1:]

# %%
for t in Population_df.columns[1:]:
    Population_df = Population_df.rename(columns={t: t + ' Population'})
    
# Rename state column
re_Population_df = Population_df.rename(columns={'STATE':'State'})

# %%
re_Population_df.head()
# Out:
#         State  2010 Population  2011 Population  2012 Population  \
# 0     Alabama        4712651.0        4747424.0        4777326.0
# 1      Alaska         691189.0         700703.0         711139.0
# 2     Arizona        6246816.0        6337373.0        6410979.0
# 3    Arkansas        2872684.0        2895928.0        2916372.0
# 4  California       36637290.0       36969200.0       37325068.0
#
#    2013 Population  2014 Population  2015 Population  2016 Population  \
# 0        4799277.0        4817678.0        4830620.0        4841164.0
# 1         720316.0         728300.0         733375.0         736855.0
# 2        6479703.0        6561516.0        6641928.0        6728577.0
# 3        2933369.0        2947036.0        2958208.0        2968472.0
# 4       37659181.0       38066920.0       38421464.0       38654206.0
#
#    2017 Population
# 0        4850771.0
# 1         738565.0
# 2        6809946.0
# 3        2977944.0
# 4       38982847.0

# %%
merged_homeless_df = pd.merge(re_Population_df, ann_home_df, on='State')
merged_homeless_df.head()
# Out:
#         State  2010 Population  2011 Population  2012 Population  \
# 0     Alabama        4712651.0        4747424.0        4777326.0
# 1      Alaska         691189.0         700703.0         711139.0
# 2     Arizona        6246816.0        6337373.0        6410979.0
# 3    Arkansas        2872684.0        2895928.0        2916372.0
# 4  California       36637290.0       36969200.0       37325068.0
#
#    2013 Population  2014 Population  2015 Population  2016 Population  \
# 0        4799277.0        4817678.0        4830620.0        4841164.0
# 1         720316.0         728300.0         733375.0         736855.0
# 2        6479703.0        6561516.0        6641928.0        6728577.0
# 3        2933369.0        2947036.0        2958208.0        2968472.0
# 4       37659181.0       38066920.0       38421464.0       38654206.0
#
#    2017 Population  Unnamed: 0   ...      2016    2015    2014    2013  \
# 0        4850771.0           1   ...      4111    3970    4561    4689
# 1         738565.0           0   ...      1940    1956    1784    1946
# 2        6809946.0           3   ...      9707    9896   10495   10562
# 3        2977944.0           2   ...      2463    2560    2936    3812
# 4       38982847.0           4   ...    118142  115738  113952  118552
#
#      2012    2011    2010    2009    2008    2007
# 0    5209    5558    6046    6080    5387    5452
# 1    1913    2128    1863    1992    1646    1642
# 2   11302   10504   13711   14721   12488   14646
# 3    4214    3424    2762    2852    3255    3836
# 4  120098  125128  123480  123678  136531  138986
#
# [5 rows x 23 columns]

# %%
for year in Yearlist:
    merged_homeless_df['homelessnessPercentage{}'.format(year)] = (merged_homeless_df[year] / merged_homeless_df[year + ' Population']) * 100

# %%
merged_homeless_df.head()
# Out:
#         State  2010 Population  2011 Population  2012 Population  \
# 0     Alabama        4712651.0        4747424.0        4777326.0
# 1      Alaska         691189.0         700703.0         711139.0
# 2     Arizona        6246816.0        6337373.0        6410979.0
# 3    Arkansas        2872684.0        2895928.0        2916372.0
# 4  California       36637290.0       36969200.0       37325068.0
#
#    2013 Population  2014 Population  2015 Population  2016 Population  \
# 0        4799277.0        4817678.0        4830620.0        4841164.0
# 1         720316.0         728300.0         733375.0         736855.0
# 2        6479703.0        6561516.0        6641928.0        6728577.0
# 3        2933369.0        2947036.0        2958208.0        2968472.0
# 4       37659181.0       38066920.0       38421464.0       38654206.0
#
#    2017 Population  Unnamed: 0             ...                2008    2007  \
# 0        4850771.0           1             ...                5387    5452
# 1         738565.0           0             ...                1646    1642
# 2        6809946.0           3             ...               12488   14646
# 3        2977944.0           2             ...                3255    3836
# 4       38982847.0           4             ...              136531  138986
#
#    homelessnessPercentage2010  homelessnessPercentage2011  \
# 0                    0.128293                    0.117074
# 1                    0.269536                    0.303695
# 2                    0.219488                    0.165747
# 3                    0.096147                    0.118235
# 4                    0.337034                    0.338466
#
#    homelessnessPercentage2012  homelessnessPercentage2013  \
# 0                    0.109036                    0.097702
# 1                    0.269005                    0.270159
# 2                    0.176291                    0.163001
# 3                    0.144495                    0.129953
# 4                    0.321762                    0.314802
#
#    homelessnessPercentage2014  homelessnessPercentage2015  \
# 0                    0.094672                    0.082184
# 1                    0.244954                    0.266712
# 2                    0.159948                    0.148993
# 3                    0.099626                    0.086539
# 4                    0.299347                    0.301233
#
#    homelessnessPercentage2016  homelessnessPercentage2017
# 0                    0.084918                    0.078194
# 1                    0.263281                    0.249809
# 2                    0.144265                    0.131381
# 3                    0.082972                    0.082842
# 4                    0.305638                    0.337410
#
# [5 rows x 31 columns]

# %%
home_percentage_df = merged_homeless_df[['State', 'homelessnessPercentage2010', 'homelessnessPercentage2011', 'homelessnessPercentage2012',
                                        'homelessnessPercentage2013', 'homelessnessPercentage2014', 'homelessnessPercentage2015',
                                        'homelessnessPercentage2016', 'homelessnessPercentage2017']]

# %%
home_percentage_df.head()
# Out:
#         State  homelessnessPercentage2010  homelessnessPercentage2011  \
# 0     Alabama                    0.128293                    0.117074
# 1      Alaska                    0.269536                    0.303695
# 2     Arizona                    0.219488                    0.165747
# 3    Arkansas                    0.096147                    0.118235
# 4  California                    0.337034                    0.338466
#
#    homelessnessPercentage2012  homelessnessPercentage2013  \
# 0                    0.109036                    0.097702
# 1                    0.269005                    0.270159
# 2                    0.176291                    0.163001
# 3                    0.144495                    0.129953
# 4                    0.321762                    0.314802
#
#    homelessnessPercentage2014  homelessnessPercentage2015  \
# 0                    0.094672                    0.082184
# 1                    0.244954                    0.266712
# 2                    0.159948                    0.148993
# 3                    0.099626                    0.086539
# 4                    0.299347                    0.301233
#
#    homelessnessPercentage2016  homelessnessPercentage2017
# 0                    0.084918                    0.078194
# 1                    0.263281                    0.249809
# 2                    0.144265                    0.131381
# 3                    0.082972                    0.082842
# 4                    0.305638                    0.337410

# %%
home_percentage_df.to_csv("dataframes/Homeless_Percentage_by_Year.csv", header=True)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-97-96133a0dce9f> in <module>()
# ----> 1 home_percentage_df.to_csv("dataframes/Homeless_Percentage_by_Year.csv", header=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1743                                  doublequote=doublequote,
#    1744                                  escapechar=escapechar, decimal=decimal)
# -> 1745         formatter.save()
#    1746
#    1747         if path_or_buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     154             f, handles = _get_handle(self.path_or_buf, self.mode,
#     155                                      encoding=encoding,
# --> 156                                      compression=self.compression)
#     157             close = True
#     158
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     398         elif encoding:
#     399             # Python 3 and encoding
# --> 400             f = open(path_or_buf, mode, encoding=encoding)
#     401         elif is_text:
#     402             # Python 3 and no explicit encoding
#
# PermissionError: [Errno 13] Permission denied: 'dataframes/Homeless_Percentage_by_Year.csv'

# %%
# Read csv containing median household prices for each state by year
median_hs_pr_df = pd.read_csv("../Desthy/Dataframes/State_MedianListingPrice_AllHomes.csv") 
median_hs = median_hs_pr_df.rename(columns={'State':'RegionName', 'State Full Name':'State'})

# %%
median_hs.head()
# Out:
#   RegionName       State  SizeRank         2010         2011         2012  \
# 0         CA  California         1  331354.1667  296987.5000  308158.8333
# 1         TX       Texas         2  171324.5833  168918.6667  172219.1667
# 2         NY    New York         3  345016.5833  317552.0000  306182.5000
# 3         FL     Florida         4  187158.3333  175891.5833  179162.5000
# 4         IL    Illinois         5  204158.3333  176166.6667  159783.3333
#
#           2013         2014         2015         2016         2017  \
# 0  390208.2500  418516.6667  440640.6667  479724.9167  500381.4583
# 1  187101.3333  212438.3333  245033.0833  255709.7500  268202.7917
# 2  305825.0000  324191.5833  330624.3333  340693.0417  352726.0417
# 3  198024.1667  215341.6667  236499.0000  259156.6667  279908.7500
# 4  164489.5833  180408.3333  192858.3333  202632.3333  215231.2500
#
#           2018       2019
# 0  527849.1667  533111.25
# 1  275731.6667  278067.50
# 2  387716.6667  414725.00
# 3  291312.1667  295975.00
# 4  228915.8333  235975.00

# %%
Yearlist2 = median_hs.columns[3:]

# %%
for year in Yearlist2:
    median_hs = median_hs.rename(columns={'{}'.format(year): 'medianHousePrice{}'.format(year)})

# %%
median_hs.head()
# Out:
#   RegionName       State  SizeRank  medianHousePrice2010  \
# 0         CA  California         1           331354.1667
# 1         TX       Texas         2           171324.5833
# 2         NY    New York         3           345016.5833
# 3         FL     Florida         4           187158.3333
# 4         IL    Illinois         5           204158.3333
#
#    medianHousePrice2011  medianHousePrice2012  medianHousePrice2013  \
# 0           296987.5000           308158.8333           390208.2500
# 1           168918.6667           172219.1667           187101.3333
# 2           317552.0000           306182.5000           305825.0000
# 3           175891.5833           179162.5000           198024.1667
# 4           176166.6667           159783.3333           164489.5833
#
#    medianHousePrice2014  medianHousePrice2015  medianHousePrice2016  \
# 0           418516.6667           440640.6667           479724.9167
# 1           212438.3333           245033.0833           255709.7500
# 2           324191.5833           330624.3333           340693.0417
# 3           215341.6667           236499.0000           259156.6667
# 4           180408.3333           192858.3333           202632.3333
#
#    medianHousePrice2017  medianHousePrice2018  medianHousePrice2019
# 0           500381.4583           527849.1667             533111.25
# 1           268202.7917           275731.6667             278067.50
# 2           352726.0417           387716.6667             414725.00
# 3           279908.7500           291312.1667             295975.00
# 4           215231.2500           228915.8333             235975.00

# %%
median_data = median_hs[['State', 'medianHousePrice2010', 'medianHousePrice2011', 'medianHousePrice2012',
                                        'medianHousePrice2013', 'medianHousePrice2014', 'medianHousePrice2015',
                                        'medianHousePrice2016', 'medianHousePrice2017']]

# %%
median_data.head()
# Out:
#         State  medianHousePrice2010  medianHousePrice2011  \
# 0  California           331354.1667           296987.5000
# 1       Texas           171324.5833           168918.6667
# 2    New York           345016.5833           317552.0000
# 3     Florida           187158.3333           175891.5833
# 4    Illinois           204158.3333           176166.6667
#
#    medianHousePrice2012  medianHousePrice2013  medianHousePrice2014  \
# 0           308158.8333           390208.2500           418516.6667
# 1           172219.1667           187101.3333           212438.3333
# 2           306182.5000           305825.0000           324191.5833
# 3           179162.5000           198024.1667           215341.6667
# 4           159783.3333           164489.5833           180408.3333
#
#    medianHousePrice2015  medianHousePrice2016  medianHousePrice2017
# 0           440640.6667           479724.9167           500381.4583
# 1           245033.0833           255709.7500           268202.7917
# 2           330624.3333           340693.0417           352726.0417
# 3           236499.0000           259156.6667           279908.7500
# 4           192858.3333           202632.3333           215231.2500

# %%
median_data.to_csv("dataframes/Median_House_Price_by_Year.csv", header=True)

# %%
Price_to_Homelessness_df = pd.merge(median_data, home_percentage_df, on='State')
Price_to_Homelessness_df.head()
# Out:
#         State  medianHousePrice2010  medianHousePrice2011  \
# 0  California           331354.1667           296987.5000
# 1       Texas           171324.5833           168918.6667
# 2    New York           345016.5833           317552.0000
# 3     Florida           187158.3333           175891.5833
# 4    Illinois           204158.3333           176166.6667
#
#    medianHousePrice2012  medianHousePrice2013  medianHousePrice2014  \
# 0           308158.8333           390208.2500           418516.6667
# 1           172219.1667           187101.3333           212438.3333
# 2           306182.5000           305825.0000           324191.5833
# 3           179162.5000           198024.1667           215341.6667
# 4           159783.3333           164489.5833           180408.3333
#
#    medianHousePrice2015  medianHousePrice2016  medianHousePrice2017  \
# 0           440640.6667           479724.9167           500381.4583
# 1           245033.0833           255709.7500           268202.7917
# 2           330624.3333           340693.0417           352726.0417
# 3           236499.0000           259156.6667           279908.7500
# 4           192858.3333           202632.3333           215231.2500
#
#    homelessnessPercentage2010  homelessnessPercentage2011  \
# 0                    0.337034                    0.338466
# 1                    0.144460                    0.148990
# 2                    0.341169                    0.328689
# 3                    0.310891                    0.303321
# 4                    0.112943                    0.109529
#
#    homelessnessPercentage2012  homelessnessPercentage2013  \
# 0                    0.321762                    0.314802
# 1                    0.135079                    0.115506
# 2                    0.358622                    0.397341
# 3                    0.292134                    0.250702
# 4                    0.110294                    0.104486
#
#    homelessnessPercentage2014  homelessnessPercentage2015  \
# 0                    0.299347                    0.301233
# 1                    0.109210                    0.089221
# 2                    0.411292                    0.448580
# 3                    0.214557                    0.182737
# 4                    0.101851                    0.102355
#
#    homelessnessPercentage2016  homelessnessPercentage2017
# 0                    0.305638                    0.337410
# 1                    0.085775                    0.085880
# 2                    0.438392                    0.452076
# 3                    0.168347                    0.158740
# 4                    0.090183                    0.084002

# %%
Price_to_Homelessness_df.to_csv("dataframes/Price_to_Homelessness.csv", header=True)

# %%
Unemployment_df = pd.read_csv("../Desthy/Dataframes/Annual_Average_Unemployment_Rates_By_State.csv")
Unemployment_df.head()
# Out:
#           State State Full Name Continental US  2018  2017  2016  2015  2014  \
# 0  United State   United States            Yes   3.9   4.4   4.9   5.3   6.2
# 1            AL         Alabama            Yes   3.9   4.4   5.8   6.1   6.8
# 2            AK          Alaska            Yes   6.6   7.0   6.9   6.5   6.9
# 3            AZ         Arizona            Yes   4.8   4.9   5.4   6.1   6.8
# 4            AR        Arkansas            Yes   3.7   3.7   4.0   5.0   6.0
#
#    2013  2012  ...   2009  2008  2007  2006  2005  2004  2003  2002  2001  \
# 0   7.4   8.1  ...    9.3   5.8   4.6   4.6   5.1   5.5   6.0   5.8   4.7
# 1   7.2   8.0  ...   11.0   5.7   4.0   4.0   4.5   5.7   6.0   5.9   5.1
# 2   7.0   7.1  ...    7.7   6.7   6.3   6.6   6.9   7.5   7.8   7.3   6.4
# 3   7.7   8.3  ...    9.9   6.2   3.9   4.2   4.7   5.0   5.7   6.1   4.8
# 4   7.2   7.6  ...    7.8   5.5   5.3   5.2   5.2   5.7   5.9   5.5   5.0
#
#    2000
# 0   4.0
# 1   4.6
# 2   6.4
# 3   4.0
# 4   4.3
#
# [5 rows x 22 columns]

# %%
for year in Yearlist:
    Unemployment_df = Unemployment_df.rename(columns={'{}'.format(year): 'unemployementRate{}'.format(year)})

# %%
Unemployment_df.head()
# Out:
#           State State Full Name Continental US  2018  unemployementRate2017  \
# 0  United State   United States            Yes   3.9                    4.4
# 1            AL         Alabama            Yes   3.9                    4.4
# 2            AK          Alaska            Yes   6.6                    7.0
# 3            AZ         Arizona            Yes   4.8                    4.9
# 4            AR        Arkansas            Yes   3.7                    3.7
#
#    unemployementRate2016  unemployementRate2015  unemployementRate2014  \
# 0                    4.9                    5.3                    6.2
# 1                    5.8                    6.1                    6.8
# 2                    6.9                    6.5                    6.9
# 3                    5.4                    6.1                    6.8
# 4                    4.0                    5.0                    6.0
#
#    unemployementRate2013  unemployementRate2012  ...   2009  2008  2007  2006  \
# 0                    7.4                    8.1  ...    9.3   5.8   4.6   4.6
# 1                    7.2                    8.0  ...   11.0   5.7   4.0   4.0
# 2                    7.0                    7.1  ...    7.7   6.7   6.3   6.6
# 3                    7.7                    8.3  ...    9.9   6.2   3.9   4.2
# 4                    7.2                    7.6  ...    7.8   5.5   5.3   5.2
#
#    2005  2004  2003  2002  2001  2000
# 0   5.1   5.5   6.0   5.8   4.7   4.0
# 1   4.5   5.7   6.0   5.9   5.1   4.6
# 2   6.9   7.5   7.8   7.3   6.4   6.4
# 3   4.7   5.0   5.7   6.1   4.8   4.0
# 4   5.2   5.7   5.9   5.5   5.0   4.3
#
# [5 rows x 22 columns]

# %%
Yearlist
# Out:
# Index(['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017'], dtype='object')

# %%
new_unemploy_df = Unemployment_df[['State Full Name','unemployementRate2010', 'unemployementRate2011', 'unemployementRate2012', 'unemployementRate2013', 'unemployementRate2014', 'unemployementRate2015', 'unemployementRate2016', 'unemployementRate2017']]
new_unemploy_df = new_unemploy_df.rename(columns={'State Full Name': 'State'})

# %%
new_unemploy_df.head()
# Out:
#            State  unemployementRate2010  unemployementRate2011  \
# 0  United States                    9.6                    8.9
# 1        Alabama                   10.5                    9.6
# 2         Alaska                    7.9                    7.6
# 3        Arizona                   10.4                    9.5
# 4       Arkansas                    8.2                    8.3
#
#    unemployementRate2012  unemployementRate2013  unemployementRate2014  \
# 0                    8.1                    7.4                    6.2
# 1                    8.0                    7.2                    6.8
# 2                    7.1                    7.0                    6.9
# 3                    8.3                    7.7                    6.8
# 4                    7.6                    7.2                    6.0
#
#    unemployementRate2015  unemployementRate2016  unemployementRate2017
# 0                    5.3                    4.9                    4.4
# 1                    6.1                    5.8                    4.4
# 2                    6.5                    6.9                    7.0
# 3                    6.1                    5.4                    4.9
# 4                    5.0                    4.0                    3.7

# %%
employment_vs_homeless = pd.merge(home_percentage_df, new_unemploy_df, on='State')

# %%
employment_vs_homeless.head()
# Out:
#         State  homelessnessPercentage2010  homelessnessPercentage2011  \
# 0     Alabama                    0.128293                    0.117074
# 1      Alaska                    0.269536                    0.303695
# 2     Arizona                    0.219488                    0.165747
# 3    Arkansas                    0.096147                    0.118235
# 4  California                    0.337034                    0.338466
#
#    homelessnessPercentage2012  homelessnessPercentage2013  \
# 0                    0.109036                    0.097702
# 1                    0.269005                    0.270159
# 2                    0.176291                    0.163001
# 3                    0.144495                    0.129953
# 4                    0.321762                    0.314802
#
#    homelessnessPercentage2014  homelessnessPercentage2015  \
# 0                    0.094672                    0.082184
# 1                    0.244954                    0.266712
# 2                    0.159948                    0.148993
# 3                    0.099626                    0.086539
# 4                    0.299347                    0.301233
#
#    homelessnessPercentage2016  homelessnessPercentage2017  \
# 0                    0.084918                    0.078194
# 1                    0.263281                    0.249809
# 2                    0.144265                    0.131381
# 3                    0.082972                    0.082842
# 4                    0.305638                    0.337410
#
#    unemployementRate2010  unemployementRate2011  unemployementRate2012  \
# 0                   10.5                    9.6                    8.0
# 1                    7.9                    7.6                    7.1
# 2                   10.4                    9.5                    8.3
# 3                    8.2                    8.3                    7.6
# 4                   12.2                   11.7                   10.4
#
#    unemployementRate2013  unemployementRate2014  unemployementRate2015  \
# 0                    7.2                    6.8                    6.1
# 1                    7.0                    6.9                    6.5
# 2                    7.7                    6.8                    6.1
# 3                    7.2                    6.0                    5.0
# 4                    8.9                    7.5                    6.2
#
#    unemployementRate2016  unemployementRate2017
# 0                    5.8                    4.4
# 1                    6.9                    7.0
# 2                    5.4                    4.9
# 3                    4.0                    3.7
# 4                    5.5                    4.8

# %%
employment_vs_homeless.to
